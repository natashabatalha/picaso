# %% [markdown]
# # One-Dimensional Climate Models: Brown Dwarfs w/ Clouds
#
# In this tutorial you will learn how to run 1-D climate models for brown dwarfs with Virga clouds included self-consistently!
#
# You should already be familiar with running 1-D climate models with running a [simple clear brown dwarf model](https://natashabatalha.github.io/picaso/notebooks/climate/12a_BrownDwarf.html)
#
# What you need to have downloaded for clouds to work:
# [Virga](https://natashabatalha.github.io/virga/installation.html)

# %%
import warnings
warnings.filterwarnings('ignore')
import picaso.justdoit as jdi
import picaso.justplotit as jpi
import virga.justdoit as vj
import virga.justplotit as cldplt
jpi.output_notebook()
import astropy.units as u
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xarray
from bokeh.plotting import show, figure
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ae5a1bd4-4f3d-408f-81ba-be9ec9531af0">Loading BokehJS ...</span>
#     </div>

# %%
#1 ck tables from roxana
mh = '+000'#'+0.0' #log metallicity
CtoO = '100'#'1.0' # CtoO ratio

ck_db = f'/data/kcoeff_2020_v3/sonora_2020_feh{mh}_co_{CtoO}.data.196'
ck_db = f'/Users/nbatalh1/Documents/data/kcoeff_asci/sonora_2020_feh{mh}_co_{CtoO}.data.196'
print(ck_db)
#sonora bobcat cloud free structures file
sonora_profile_db = '/Users/nbatalh1/Documents/data/sonora_bobcat/structures_m+0.0'
# Out:
# /Users/nbatalh1/Documents/data/kcoeff_asci/sonora_2020_feh+000_co_100.data.196

# %%
cl_run = jdi.inputs(calculation="browndwarf", climate = True) # start a calculation

#note you need to put the climate keyword to be True in order to do so
# now you need to add these parameters to your calculation

teff= 200 # Effective Temperature of your Brown Dwarf in K
grav = 1000 # Gravity of your brown dwarf in m/s/s

cl_run.gravity(gravity=grav, gravity_unit=u.Unit('m/(s**2)')) # input gravity
cl_run.effective_temp(teff) # input effective temperature

opacity_ck = jdi.opannection(ck_db=ck_db, method='preweighted') # grab your opacities

# %%
nlevel = 91 # number of plane-parallel levels in your code

pressure_bobcat,temp_bobcat = np.loadtxt(jdi.os.path.join(
                            sonora_profile_db,f"t{teff}g{grav}nc_m0.0.dat"),
                            usecols=[1,2],unpack=True, skiprows = 1)

# %%
nofczns = 1 # number of convective zones initially

# for the sake of time in this tutorial, I set it to a higher layer because I know where it should be in this case. 
# In general for clouds it is better to start deeper in the atmosphere and work your way up. It just takes a lot more time unfortunately.
nstr_upper = 52 # top most level of guessed convective zone 

nstr_deep = nlevel - 2 # this is always the case. Dont change this

nstr = np.array([0,nstr_upper,nstr_deep,0,0,0])

# Here are some other parameters needed for the code.
rfacv = 0.0 #we are focused on a brown dwarf so let's keep this as is

# %% [markdown]
# If you are unfamiliar with Virga, we highly recommend going through the [tutorials](https://natashabatalha.github.io/virga/tutorials.html) to understand the basics of how we generate those clouds before pairing them with the 1-D climate models here. It is also necessarry to have the mieff files generated for the cloud species you want to include.
#
# Below, we run Virga as normal to initiate our cloud run. Note, though the function is identical when we run `virga` here in climate, we are just doing it to initiate our inputs. So this virga run does not actually compute a cloud. This behavior is normal and your cloud model will still run within the climate code.

# %%
virga_dir = '//Users/nbatalh1/Documents/data/virga' # path to virga directory with the Mie scatering files

# %%
cl_run.inputs_climate(temp_guess= temp_bobcat, pressure= pressure_bobcat,
                      nstr = nstr, nofczns = nofczns , rfacv = rfacv)#, #mh = '0.0', CtoO = '1.0', 
                      #cloudy = True)
#cl_run.atmosphere(cold_trap=True)
cl_run.virga(condensates = ['H2O'],directory = virga_dir, mh=1,fsed = 8.0)

# %%
out = cl_run.climate(opacity_ck, save_all_profiles=True,with_spec=False,
                     self_consistent_kzz=True)
# Out:
# TODO: would love to have a full summary of what the run is here so users can double check they are happy with their inputss
# I am updating kzz
# I dont have fluxes, let me compute them
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 7.306406045821589  Tau tolerance is  1.461281209164318
# Iteration number  0 , min , max temp  76.9389143655791 1201.8943899107073 , flux balance  -0.3544863199482797
# Iteration number  1 , min , max temp  78.83745521802955 1202.226995869733 , flux balance  -0.3537146857323902
# Iteration number  2 , min , max temp  80.62579515149656 1202.5877982376487 , flux balance  -0.3528768524530439
# Iteration number  3 , min , max temp  82.32034847761021 1202.9791105604538 , flux balance  -0.3519672473306058
# Iteration number  4 , min , max temp  83.93430132065211 1203.4036099429832 , flux balance  -0.35097941128902793
# Iteration number  5 , min , max temp  85.47899637989624 1203.864328689533 , flux balance  -0.34990582802095926
# Iteration number  6 , min , max temp  86.96402259364886 1204.3642358931374 , flux balance  -0.3487379482275919
# Iteration number  7 , min , max temp  88.39736700535704 1204.9077492311674 , flux balance  -0.34746618531504053
# Iteration number  8 , min , max temp  89.78562277013252 1205.4992707937429 , flux balance  -0.34607996230546795
# Iteration number  9 , min , max temp  91.13422476347237 1206.1434532815333 , flux balance  -0.3445678050085784
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 6.464843752190049  Tau tolerance is  4.214401478773749
# Big iteration is  91.13422476347237 0
# Iteration number  0 , min , max temp  91.82504373150599 1207.9747128931442 , flux balance  -0.3597780010007496
# Iteration number  1 , min , max temp  92.5964544970809 1209.8711273631054 , flux balance  -0.35549424879010844
# Iteration number  2 , min , max temp  93.44320207207252 1211.8341816597588 , flux balance  -0.351034951738233
# Iteration number  3 , min , max temp  94.3570194992977 1213.8710332574838 , flux balance  -0.34638355079260535
# Iteration number  4 , min , max temp  95.32734456408188 1215.9860555760545 , flux balance  -0.34152681029173415
# Iteration number  5 , min , max temp  96.3419575972681 1218.1836354931852 , flux balance  -0.33645103124067083
# Iteration number  6 , min , max temp  97.38839139305895 1220.4675634491123 , flux balance  -0.33114222437598556
# Iteration number  7 , min , max temp  98.45490613028309 1222.8418928906988 , flux balance  -0.3255863883900613
# Iteration number  8 , min , max temp  99.53091550402847 1225.3131939219136 , flux balance  -0.3197695002450332
# Iteration number  9 , min , max temp  100.60759381028663 1227.8840399762778 , flux balance  -0.31367815590644316
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 6.589885200623385  Tau tolerance is  6.823349669594376
# Profile converged before itmx
# I am updating kzz
# I dont have fluxes, let me compute them
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 6.5479059399448225  Tau tolerance is  9.450907897708019
# Iteration number  0 , min , max temp  99.85373676782582 1234.1369024845865 , flux balance  -0.3327734881959927
# Iteration number  1 , min , max temp  99.0900640584263 1240.3259063401226 , flux balance  -0.31878361152139173
# Iteration number  2 , min , max temp  98.31700561499632 1246.4490425937183 , flux balance  -0.304723045894729
# Iteration number  3 , min , max temp  97.5349754470087 1252.504092282409 , flux balance  -0.29059661691472755
# Iteration number  4 , min , max temp  96.7443834161557 1258.4971525227088 , flux balance  -0.2764077097456075
# Iteration number  5 , min , max temp  95.9456467910285 1264.4292927831514 , flux balance  -0.2621569893785665
# Iteration number  6 , min , max temp  95.13912236692215 1270.2906642865446 , flux balance  -0.24785019861018406
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 6.044380275388438  Tau tolerance is  9.737790410223326
# Big iteration is  95.13912236692215 0
# Iteration number  0 , min , max temp  94.96960648872357 1277.6808753530245 , flux balance  -0.24933687564055265
# Iteration number  1 , min , max temp  94.80440941491106 1285.0500243976214 , flux balance  -0.23142644912612756
# Iteration number  2 , min , max temp  94.64439316913634 1292.4042357190187 , flux balance  -0.21322517886480447
# Iteration number  3 , min , max temp  94.49045802225007 1299.7483104045643 , flux balance  -0.19473272354232304
# Iteration number  4 , min , max temp  94.3435533778917 1307.0725702261727 , flux balance  -0.1759481089480927
# Iteration number  5 , min , max temp  94.20453617118832 1314.378759331002 , flux balance  -0.15687074526719666
# Iteration number  6 , min , max temp  94.07425650763396 1321.6689277220435 , flux balance  -0.13750050254648197
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 6.267106502211231  Tau tolerance is  7.461670434307425
# Big iteration is  94.07425650763396 1
# Iteration number  0 , min , max temp  94.16440157456921 1326.0716921829246 , flux balance  -0.16751782071665663
# Iteration number  1 , min , max temp  94.27723496764312 1330.51507965526 , flux balance  -0.1565827411931659
# Iteration number  2 , min , max temp  94.4132970814308 1335.007324605902 , flux balance  -0.14541448332223472
# Iteration number  3 , min , max temp  94.57294276457523 1339.5437959116857 , flux balance  -0.13401462488046087
# Iteration number  4 , min , max temp  94.75630259585905 1344.1192061278198 , flux balance  -0.12238741290286669
# Iteration number  5 , min , max temp  94.96331581966642 1348.7288852063368 , flux balance  -0.11053658618590705
# Iteration number  6 , min , max temp  95.19366134845558 1353.3721232313112 , flux balance  -0.09846988761506123
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 6.409062170952183  Tau tolerance is  5.4123039418869965
# Big iteration is  95.19366134845558 2
# Iteration number  0 , min , max temp  94.55588854643798 1356.9310022667462 , flux balance  -0.13179251489005203
# Iteration number  1 , min , max temp  93.91854313604479 1360.4751615333228 , flux balance  -0.12339634017836366
# Iteration number  2 , min , max temp  93.28371549219321 1364.0014840512517 , flux balance  -0.11497217475085192
# Iteration number  3 , min , max temp  92.65356290270128 1367.5071221139272 , flux balance  -0.10652208857279591
# Iteration number  4 , min , max temp  92.03024994147012 1370.9953922831428 , flux balance  -0.09804902477454233
# Iteration number  5 , min , max temp  91.41581401106818 1374.4647196918395 , flux balance  -0.08955680490794696
# Iteration number  6 , min , max temp  90.8121022032353 1377.9080218742085 , flux balance  -0.08105006883423532
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 6.46730154075842  Tau tolerance is  5.065964160998012
# Big iteration is  90.8121022032353 3
# Iteration number  0 , min , max temp  91.24415763976322 1379.3077533882702 , flux balance  -0.11899092149982202
# Iteration number  1 , min , max temp  91.72283976354859 1380.7737213146856 , flux balance  -0.11569368772486151
# Iteration number  2 , min , max temp  92.25011070288615 1382.3079883700748 , flux balance  -0.1122319621188735
# Iteration number  3 , min , max temp  92.82670132151736 1383.9124340775745 , flux balance  -0.10860214164398678
# Iteration number  4 , min , max temp  93.4520019588087 1385.5856250546874 , flux balance  -0.10480244651339292
# Iteration number  5 , min , max temp  94.12355369504743 1387.3266434218474 , flux balance  -0.10083311456411649
# Iteration number  6 , min , max temp  94.83713795288189 1389.1329887822972 , flux balance  -0.09669645292189745
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Doing clouds: Max TAUCLD diff is 5.309743143099505  Tau tolerance is  4.661290231596546
# Big iteration is  94.83713795288189 4
# Not converged
# I am updating kzz
# I dont have fluxes, let me compute them
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 3.4274419618634795  Tau tolerance is  5.358875391712962
# Iteration number  0 , min , max temp  94.20892714129943 1392.2346002187185 , flux balance  -0.13466982061309002
# Iteration number  1 , min , max temp  93.59587861274585 1396.8870450724914 , flux balance  -0.12402978631907433
# Iteration number  2 , min , max temp  92.99683952928518 1401.4219044550812 , flux balance  -0.11355570052645714
# Iteration number  3 , min , max temp  92.41051452484638 1405.8405528792266 , flux balance  -0.1032434021202661
# Iteration number  4 , min , max temp  91.83556615248708 1410.1466759705127 , flux balance  -0.09308838235630656
# Iteration number  5 , min , max temp  91.27068133558109 1414.3447278602594 , flux balance  -0.08308427065043622
# Iteration number  6 , min , max temp  90.71462566694734 1418.443238959062 , flux balance  -0.07322612427933607
# Iteration number  7 , min , max temp  90.16622544758539 1422.4450900503966 , flux balance  -0.06351029609949799
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 3.458601251311484  Tau tolerance is  5.420752964692061
# Big iteration is  90.16622544758539 0
# Iteration number  0 , min , max temp  90.90865255433698 1422.9784723102475 , flux balance  -0.09043796206479794
# Iteration number  1 , min , max temp  91.68209198518323 1423.558760177356 , flux balance  -0.08909859544077231
# Iteration number  2 , min , max temp  92.48833911902203 1424.1889135108338 , flux balance  -0.08764260779156377
# Iteration number  3 , min , max temp  93.32830797099263 1424.8716157886543 , flux balance  -0.08606199294846732
# Iteration number  4 , min , max temp  94.20167183300313 1425.60994394911 , flux balance  -0.08434935721497636
# Iteration number  5 , min , max temp  95.10665786371703 1426.406559307215 , flux balance  -0.08249829882113799
# Iteration number  6 , min , max temp  96.03990559867165 1427.2633539045416 , flux balance  -0.08050366952816611
# Iteration number  7 , min , max temp  96.99725693247403 1428.1817482946612 , flux balance  -0.07836168126546368
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Doing clouds: Max TAUCLD diff is 1.731907108677703  Tau tolerance is  4.878575354711117
# Profile converged before itmx
# final [ 0 51 89  0  0  0]
# I am updating kzz
# I dont have fluxes, let me compute them
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 1.6745801420449666  Tau tolerance is  4.197277904566583
# Iteration number  0 , min , max temp  96.03104116768009 1431.5163041816268 , flux balance  -0.1013312047874493
# Iteration number  1 , min , max temp  95.06595557558893 1434.772764881353 , flux balance  -0.09402649731583992
# Iteration number  2 , min , max temp  94.10254852924906 1437.959202025098 , flux balance  -0.08683218386673767
# Iteration number  3 , min , max temp  93.14132510790358 1441.0764357352289 , flux balance  -0.07974594315974554
# Iteration number  4 , min , max temp  92.18269616054127 1444.123086345406 , flux balance  -0.07276517909267159
# Iteration number  5 , min , max temp  91.22704946613571 1447.1036120258145 , flux balance  -0.0658871002715123
# Iteration number  6 , min , max temp  90.27472944339748 1450.0220350388104 , flux balance  -0.05910886096092605
# Iteration number  7 , min , max temp  89.3260476641547 1452.8827942762332 , flux balance  -0.05242764297567953
# Iteration number  8 , min , max temp  88.38131488756034 1455.6851600124926 , flux balance  -0.045840772850050615
# Iteration number  9 , min , max temp  87.44078319148362 1458.4291197425252 , flux balance  -0.03934560949251186
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 3.3329834126094564  Tau tolerance is  4.419753317456904
# Big iteration is  87.44078319148362 0

# %% [markdown]
# ## Plot the P-T Profile

# %% [markdown]
# Before we plot the PT profile of the model, we want to grab the condensation curve for H2O just to help us visualize where in the atmosphere we expect the cloud to start forming. To the left of this condensation curve is where we expect the H2O vapour to condense into a cloud.

# %%
h2o_cond_p, h2o_cond_t = vj.condensation_t('H2O', 1, 2.2, pressure = out['pressure'])

# %%
pressure_bobcat,temp_bobcat = np.loadtxt(jdi.os.path.join(
                            sonora_profile_db,f"t{teff}g{grav}nc_m0.0.dat"),
                            usecols=[1,2],unpack=True, skiprows = 1)
plt.figure(figsize=(8,6))
plt.ylabel("Pressure [Bars]")
plt.xlabel('Temperature [K]')
plt.xlim(0,max(out['temperature'])+50)
plt.ylim(3e3,1e-3)

plt.plot(h2o_cond_t,h2o_cond_p, 'b', label = 'H2O Condensation Curve')
plt.semilogy(temp_bobcat,pressure_bobcat,color="k",linestyle="--",linewidth=3,label="Sonora Bobcat")

plt.semilogy(out['temperature'],out['pressure'],label="Our Cloudy Run")

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Now you should be able to see a mostly smooth PT profile that's a little warmer than the cloud-free Sonora Bobcat profile. Even though it looks warmer, the actual effective temperature of the object is the same because the water cloud opacity blocks out some of the flux.
#
# As you may know (or will find out) clouds are really difficult to converge models for especially with H2O clouds in cold regions for example. To learn more about common signs that you should look for to identify "bad" models, take a look at the [Diagnostics notebook]()

# %% [markdown]
# ## Looking at the Cloud Properties
#
# If you look at the climate output now, you will notice a couple of new keys in the dictionary that helps you look at the cloud properties

# %%
out.keys()
# Out:
# dict_keys(['pressure', 'temperature', 'ptchem_df', 'dtdp', 'cvz_locs', 'flux_ir_attop', 'fnet/fnetir', 'converged', 'flux_balance', 'cld_df', 'virga_output', 'all_profiles', 'all_opd', 'all_kzz'])

# %% [markdown]
# `cld_df` and `virga_output` are the two important dictionary key outputs for cloudy runs. `cld_df` is in the format to be used to generate spectra.

# %%
out['cld_df']
# Out:
#        opd   w0   g0    pressure    wavenumber
# 0      0.0  0.0  0.0    0.000195  37331.820150
# 1      0.0  0.0  0.0    0.000195  34848.475344
# 2      0.0  0.0  0.0    0.000195  32051.251233
# 3      0.0  0.0  0.0    0.000195  29670.297718
# 4      0.0  0.0  0.0    0.000195  27619.029732
# ...    ...  ...  ...         ...           ...
# 17635  0.0  0.0  0.0  918.619692    185.599999
# 17636  0.0  0.0  0.0  918.619692    135.699994
# 17637  0.0  0.0  0.0  918.619692    102.300002
# 17638  0.0  0.0  0.0  918.619692     72.049997
# 17639  0.0  0.0  0.0  918.619692     43.949998
#
# [17640 rows x 5 columns]

# %% [markdown]
# `virga_output` can then be directly used with virga functions to easily visualize the properties as well. For more details about these individual properties and how to interpret them, please take a look at the [Analyzing Your Runs](https://natashabatalha.github.io/virga/notebooks/3_AnalyzingRuns.html) virga tutorial.

# %%
show(cldplt.all_optics_1d(out['virga_output'], wave_range=[1,2]))
# Out:
#   <div id="d04df68e-d000-4a6d-bcc9-ccf0df6d29db" data-root-id="p1134" style="display: contents;"></div>

# %%
show(cldplt.all_optics(out['virga_output']))
# Out:
#   <div id="a1af9fba-d6c6-44f1-980b-30ebb75822b0" data-root-id="p1307" style="display: contents;"></div>

# %%
show(cldplt.opd_by_gas(out['virga_output']))
# Out:
#   <div id="f0d1fc61-6608-4943-803b-91d0af26a1d7" data-root-id="p1318" style="display: contents;"></div>

# %%
show(cldplt.condensate_mmr(out['virga_output']))
# Out:
#   <div id="d38951f8-d198-45a7-ae2d-71ee1a79b955" data-root-id="p1365" style="display: contents;"></div>

# %% [markdown]
# ## Cloudy vs Clear Spectra

# %% [markdown]
# Now we can generate the spectrum for the cloudy run. This is exactly like how we generate any other thermal emission spectrum except this time we add in the cloud profile. (You may have done this before if you've tried to use a post-processed virga cloud)

# %%
opa_mon = jdi.opannection(wave_range=[0.3,15])

hi_res = jdi.inputs(calculation="browndwarf") # start a calculation
teff= 200 # Effective Temperature of your Brown Dwarf in K
grav = 1000 # Gravity of your brown dwarf in m/s/s
hi_res.gravity(gravity=grav, gravity_unit=u.Unit('m/(s**2)')) # input gravity

hi_res.atmosphere(df=out['ptchem_df'])

# now let's add the cloud optical properties
hi_res.clouds(df=out['cld_df'])

df_spec = hi_res.spectrum(opa_mon, calculation='thermal',full_output=True)

#converts from picaso default units (can also specify original unit if different from picaso via kwarg f_unit and xgrid_unit)
fluxnu= jdi.convert_flux_units(df_spec['wavenumber'], df_spec['thermal'], to_f_unit = 'erg*cm^(-2)*s^(-1)*Hz^(-1)')

df_spec['fluxnu'] = fluxnu
wno,fp = jdi.mean_regrid(df_spec['wavenumber'], fluxnu, R=200) #wavenumber, erg/cm2/s/Hz

# %%
jpi.show(jpi.spectrum(wno,fp,x_axis_type='log',y_axis_type='log'))
# Out:
#   <div id="af1a09ad-cc96-49af-8f40-ec6853d12813" data-root-id="p1412" style="display: contents;"></div>

# %% [markdown]
# Now let's load in a Sonora Bobcat spectrum to compare what it looks like. This specific case has been included in this directory for ease of access but to compare other temperatures you will have to download the full [Sonora Bobcat](https://zenodo.org/records/5063476) set of models

# %%
teff = 200
grav = 1000

wave_bobcat,flux_bobcat = np.loadtxt(f"sp_t200g1000nc_m0.0",
                            usecols=[0,1],unpack=True, skiprows = 2)

# %%
# now let's regrid the spectra to R=200 to make sure the two spectra are on the same grid
wno_bobcat, fp_bobcat = jdi.mean_regrid(1e4/wave_bobcat,flux_bobcat,R=200)

# %%
fig = plt.figure(figsize=(12,6))
plt.loglog(1e4/wno_bobcat,fp_bobcat, 'k', label = 'Sonora Bobcat')
plt.loglog(1e4/wno,fp, label = 'Our Cloudy Run')
plt.xlabel('Wavelength [micron]')
plt.ylabel('F$_\\nu$ [erg/cm$^2$/s/Hz]')
plt.xlim(0.4,12)
plt.legend()
plt.show()

# %% [markdown]
# So here you can see the large water cloud feature aroun 4-5 micron where the flux from this brown dwarf is being surpressed by the large water cloud opacity

# %% [markdown]
# ## Patchy Clouds

# %% [markdown]
# Clouds are hard...Sometimes they don't behave nicely with static 1-D climate models. To alleviate this or to represent the reality that clouds may not be uniformly covering the entire atmosphere, where we see variability in brown dwarfs, we can run patchy clouds! For more on this, you can  read [Morley et al. 2014a](https://ui.adsabs.harvard.edu/abs/2014ApJ...787...78M/abstract) and [Morley et al. 2014b](https://ui.adsabs.harvard.edu/abs/2014ApJ...789L..14M/abstract)
#
# Here we include a few new parameters for patchy clouds
# 1. `do_holes` : (bool) Default = False. Turn on/off patchy clouds
# 2. `fhole` : (float) This is a value between 0 and 1. E.g. 0.9 represents 90% clear and 10% cloudy
# 3. `fthin_cld` : (float) This is a value between 0 and 1, it allows you to make the clear column have the slightest of clouds. 0 is completely clear, 1 is completely cloudy
#
# Typically, it's easier to think about this using just fhole and ignoring fthin_cld. Use fthin_cld only if you're trying to really model complex systems or to build an intuition about clouds!
#
# Here we're going to initiate a new climate calculation:

# %%
cl_run = jdi.inputs(calculation="browndwarf", climate = True) # start a calculation

#note you need to put the climate keyword to be True in order to do so
# now you need to add these parameters to your calculation

teff= 200 # Effective Temperature of your Brown Dwarf in K
grav = 1000 # Gravity of your brown dwarf in m/s/s

cl_run.gravity(gravity=grav, gravity_unit=u.Unit('m/(s**2)')) # input gravity
cl_run.effective_temp(teff) # input effective temperature

opacity_ck = jdi.opannection(ck_db=ck_db,method='preweighted') # grab your opacities

# %%
nofczns = 1 # number of convective zones initially

nstr_upper = 52 # top most level of guessed convective zone 
# for the sake of time of this tutorial, I set it to 60 because I know where it should be in this case. In general for clouds it is better
# to start deeper in the atmosphere and work your way up. It just takes more time.

nstr_deep = nlevel - 2 # this is always the case. Dont change this
# nstr = np.array([0,nstr_upper,nstr_deep,0,0,0]) # single convective zone

nstr = np.array([0,nstr_upper,nstr_deep,0,0,0])

# Here are some other parameters needed for the code.
rfacv = 0.0 #we are focused on a brown dwarf so let's keep this as is

# %% [markdown]
# We can initialize the inputs just like before except we are making do_holes = True and fhole = 0.5

# %%
cl_run.inputs_climate(temp_guess= temp_bobcat, pressure= pressure_bobcat,
                      nstr = nstr, nofczns = nofczns , rfacv = rfacv)

cl_run.atmosphere(cold_trap=True)
cl_run.virga(condensates = ['H2O'],directory = virga_dir, mh=1,fsed = 8.0,
             do_holes = True, fhole = 0.3, fthin_cld = 0)
# Out:
# 'Virga input set for climate code but not executed, yet'

# %%
out_patchy = cl_run.climate(opacity_ck, save_all_profiles=True,with_spec=True)
# Out:
# TODO: would love to have a full summary of what the run is here so users can double check they are happy with their inputss
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# I am updating kzz
# I dont have fluxes, let me compute them
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 7.306406082031404  Tau tolerance is  1.461281216406281
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Iteration number  0 , min , max temp  76.67214896264738 1201.7488566628979 , flux balance  -0.21343449391799968
# Iteration number  1 , min , max temp  78.43156461777691 1201.922483546485 , flux balance  -0.2128469968057718
# Iteration number  2 , min , max temp  80.13490361557778 1202.1117510619665 , flux balance  -0.21220617735510197
# Iteration number  3 , min , max temp  81.78129468258324 1202.3179242751191 , flux balance  -0.21150764437614064
# Iteration number  4 , min , max temp  83.37378116139514 1202.5425336924081 , flux balance  -0.21074608455259522
# Iteration number  5 , min , max temp  84.91629435013309 1202.787356824283 , flux balance  -0.20991531862171078
# Iteration number  6 , min , max temp  86.41242014050464 1203.0544178795587 , flux balance  -0.2090082950872014
# Iteration number  7 , min , max temp  87.86542053753018 1203.3459879638008 , flux balance  -0.20801708089855897
# Iteration number  8 , min , max temp  89.27805072043914 1203.6645740236252 , flux balance  -0.20693280908470668
# Iteration number  9 , min , max temp  90.65304961803282 1204.0127933477804 , flux balance  -0.20574571494559873
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 6.690989613670838  Tau tolerance is  4.260363133954353
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Big iteration is  90.65304961803282 0
# Iteration number  0 , min , max temp  91.74965151300243 1205.0855338440665 , flux balance  -0.21646025351087061
# Iteration number  1 , min , max temp  92.90885583372736 1206.2013112996897 , flux balance  -0.2127522072551519
# Iteration number  2 , min , max temp  94.08021377128054 1207.364974091892 , flux balance  -0.2088699300547177
# Iteration number  3 , min , max temp  95.24860637845616 1208.5817587893855 , flux balance  -0.20479600052210503
# Iteration number  4 , min , max temp  96.40730203478795 1209.8548093226402 , flux balance  -0.2005155618360086
# Iteration number  5 , min , max temp  97.55214626559344 1211.1873917908836 , flux balance  -0.19601349639115062
# Iteration number  6 , min , max temp  98.68028409989365 1212.585185861492 , flux balance  -0.19126914818532742
# Iteration number  7 , min , max temp  99.78979992818539 1214.0522221236913 , flux balance  -0.18626550168975745
# Iteration number  8 , min , max temp  100.87932066779709 1215.5921459527676 , flux balance  -0.1809861706572761
# Iteration number  9 , min , max temp  101.9477396807196 1217.208464456498 , flux balance  -0.17541498850412365
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 7.023325996361926  Tau tolerance is  7.002104822142508
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Big iteration is  101.9477396807196 1
# Iteration number  0 , min , max temp  100.94401426954286 1219.8600687655007 , flux balance  -0.18462608080392076
# Iteration number  1 , min , max temp  99.93825036000537 1222.4567865441072 , flux balance  -0.17586361237236484
# Iteration number  2 , min , max temp  98.9308108194082 1225.00421804695 , flux balance  -0.16719435832807125
# Iteration number  3 , min , max temp  97.92201638457526 1227.5037360553347 , flux balance  -0.1586159146067657
# Iteration number  4 , min , max temp  96.91215121706973 1229.9578532632408 , flux balance  -0.15012323180449522
# Iteration number  5 , min , max temp  95.90146944183626 1232.3704439057112 , flux balance  -0.14170985003156253
# Iteration number  6 , min , max temp  94.89018401593327 1234.7423620559146 , flux balance  -0.13337065097424183
# Iteration number  7 , min , max temp  93.87848667209089 1237.0756895352713 , flux balance  -0.1251034469102782
# Iteration number  8 , min , max temp  92.86655234453264 1239.3722417373642 , flux balance  -0.11690402381743048
# Iteration number  9 , min , max temp  91.85452332690237 1241.631292559157 , flux balance  -0.10876824946914213
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 6.322470712426046  Tau tolerance is  9.669655529338984
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Big iteration is  91.85452332690237 2
# Iteration number  0 , min , max temp  92.7443376253084 1242.316893862998 , flux balance  -0.13268208980504806
# Iteration number  1 , min , max temp  93.65199063848677 1243.0251514524477 , flux balance  -0.1302600830666454
# Iteration number  2 , min , max temp  94.57726068504455 1243.7567476123968 , flux balance  -0.12775234535903054
# Iteration number  3 , min , max temp  95.5193093851229 1244.5135738978868 , flux balance  -0.1251517349692391
# Iteration number  4 , min , max temp  96.47694425244369 1245.297748458265 , flux balance  -0.12245028272086006
# Iteration number  5 , min , max temp  97.44859101806688 1246.1116103033016 , flux balance  -0.11963915305805516
# Iteration number  6 , min , max temp  98.43236396553063 1246.9577103834947 , flux balance  -0.11670865685228464
# Iteration number  7 , min , max temp  99.42601028794124 1247.8388172427144 , flux balance  -0.11364821209255765
# Iteration number  8 , min , max temp  100.42720364226 1248.7568588189279 , flux balance  -0.11044643211260863
# Iteration number  9 , min , max temp  101.43345645933567 1249.7159090275852 , flux balance  -0.10709113596312099
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 5.74522761729996  Tau tolerance is  10.509926963561107
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Profile converged before itmx
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# I am updating kzz
# I dont have fluxes, let me compute them
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 5.149651256081452  Tau tolerance is  9.786102073038307
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Iteration number  0 , min , max temp  100.46676744946267 1251.5402199243379 , flux balance  -0.1162932604474387
# Iteration number  1 , min , max temp  99.50288935673144 1253.3300278492522 , flux balance  -0.11020355067175146
# Iteration number  2 , min , max temp  98.54177764027311 1255.0880723357739 , flux balance  -0.10418814395434527
# Iteration number  3 , min , max temp  97.58336219407288 1256.8173717307238 , flux balance  -0.09824119229849564
# Iteration number  4 , min , max temp  96.62756746153332 1258.5179330049452 , flux balance  -0.09236006009633549
# Iteration number  5 , min , max temp  95.67429443536605 1260.1913939943165 , flux balance  -0.08654054546193429
# Iteration number  6 , min , max temp  94.7234537383169 1261.8392918684074 , flux balance  -0.08077866164934591
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 3.5453096025388646  Tau tolerance is  8.77743797027082
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Big iteration is  94.7234537383169 0
# Iteration number  0 , min , max temp  95.38348429186891 1263.651857689939 , flux balance  -0.08678605798407837
# Iteration number  1 , min , max temp  96.06436494295667 1265.492557752581 , flux balance  -0.0804546693366481
# Iteration number  2 , min , max temp  96.76709520270043 1267.3647461808193 , flux balance  -0.0739732845525823
# Iteration number  3 , min , max temp  97.49241056342773 1269.2721610722056 , flux balance  -0.06733167320854716
# Iteration number  4 , min , max temp  98.24074316915382 1271.2141916047806 , flux balance  -0.06052665436825665
# Iteration number  5 , min , max temp  99.01206323344115 1273.1940685492473 , flux balance  -0.05354355680423694
# Iteration number  6 , min , max temp  99.80602979209847 1275.2157294737804 , flux balance  -0.046366151354202946
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 4.541784934499418  Tau tolerance is  8.56810558720574
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Profile converged before itmx
# in calc_atm turning on patchy clouds
# final [ 0 52 89  0  0  0]
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# I am updating kzz
# I dont have fluxes, let me compute them
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 3.3810215369293317  Tau tolerance is  8.830949265476875
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Iteration number  0 , min , max temp  99.0118974019673 1276.1032630246839 , flux balance  -0.05992361169383603
# Iteration number  1 , min , max temp  98.22093550424681 1276.9824511619352 , flux balance  -0.05692328407888496
# Iteration number  2 , min , max temp  97.43319383120499 1277.853533347138 , flux balance  -0.053941990472100146
# Iteration number  3 , min , max temp  96.6486630017016 1278.7166546618632 , flux balance  -0.05097924771858233
# Iteration number  4 , min , max temp  95.86727419777945 1279.5716808851757 , flux balance  -0.048034516010001145
# Iteration number  5 , min , max temp  95.08893184697381 1280.4192502273422 , flux balance  -0.04510719668610942
# Iteration number  6 , min , max temp  94.31350208313707 1281.2596034014414 , flux balance  -0.04219663906699893
# Iteration number  7 , min , max temp  93.54082617531562 1282.0925753902252 , flux balance  -0.039302129479698196
# Iteration number  8 , min , max temp  92.77075684071283 1282.9185448678425 , flux balance  -0.03642262924346148
# Iteration number  9 , min , max temp  92.003131838661 1283.7386745380113 , flux balance  -0.03355675208162766
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 4.279364439996442  Tau tolerance is  8.996892711205934
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Big iteration is  92.003131838661 0
# Iteration number  0 , min , max temp  92.88894949597899 1284.0045058761273 , flux balance  -0.04282641848006859
# Iteration number  1 , min , max temp  93.79375350214212 1284.2782684042306 , flux balance  -0.041895112534041226
# Iteration number  2 , min , max temp  94.71716694071836 1284.5605750105988 , flux balance  -0.040933843962339164
# Iteration number  3 , min , max temp  95.65823547753244 1284.8521104005627 , flux balance  -0.03994019357235082
# Iteration number  4 , min , max temp  96.61559754128449 1285.153631337975 , flux balance  -0.03891148390025472
# Iteration number  5 , min , max temp  97.58743058594513 1285.465969057527 , flux balance  -0.03784476882606112
# Iteration number  6 , min , max temp  98.57140283741204 1285.7900265421438 , flux balance  -0.036736840481309985
# Iteration number  7 , min , max temp  99.56504100496399 1286.1267708337373 , flux balance  -0.03558425296110313
# Iteration number  8 , min , max temp  100.56550679887691 1286.47722503044 , flux balance  -0.03438334700934755
# Iteration number  9 , min , max temp  101.5700187242823 1286.8424503737958 , flux balance  -0.03313030861455122
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 2.885274930027059  Tau tolerance is  9.139954580921884
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Big iteration is  101.5700187242823 1
# Iteration number  0 , min , max temp  100.61004532254215 1287.3455727186924 , flux balance  -0.03715037800507775
# Iteration number  1 , min , max temp  99.65159889505611 1287.84190031364 , flux balance  -0.03547452188910602
# Iteration number  2 , min , max temp  98.69477958485655 1288.3317613062843 , flux balance  -0.03381771187145411
# Iteration number  3 , min , max temp  97.73969859554408 1288.8154679425281 , flux balance  -0.03217898714943127
# Iteration number  4 , min , max temp  96.78641622037009 1289.2933163003747 , flux balance  -0.03055743351139059
# Iteration number  5 , min , max temp  95.8349641846947 1289.765586791086 , flux balance  -0.02895218216426621
# Iteration number  6 , min , max temp  94.88536519039076 1290.2325446008374 , flux balance  -0.02736240871677519
# Iteration number  7 , min , max temp  93.93762857963395 1290.6944407455067 , flux balance  -0.02578733001123047
# Iteration number  8 , min , max temp  92.99176478817652 1291.1515130378193 , flux balance  -0.024226201186978456
# Iteration number  9 , min , max temp  92.04776911759872 1291.6039876842408 , flux balance  -0.022678310503656617
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 1.2286271911126674  Tau tolerance is  9.16736887387511
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Big iteration is  92.04776911759872 2
# Iteration number  0 , min , max temp  92.9422424683326 1291.7760492253751 , flux balance  -0.02767918070422677
# Iteration number  1 , min , max temp  93.88451241499959 1291.9532359915197 , flux balance  -0.027081232996733946
# Iteration number  2 , min , max temp  94.85316133372365 1292.136023602078 , flux balance  -0.026463997036910714
# Iteration number  3 , min , max temp  95.83974689570299 1292.324899253301 , flux balance  -0.02582578889241933
# Iteration number  4 , min , max temp  96.83972519739007 1292.5203905755027 , flux balance  -0.02516478203379509
# Iteration number  5 , min , max temp  97.84998031476889 1292.7230946461314 , flux balance  -0.02447895452093403
# Iteration number  6 , min , max temp  98.8676902241192 1292.933908963456 , flux balance  -0.023765784903433368
# Iteration number  7 , min , max temp  99.89051550224534 1293.1532359260002 , flux balance  -0.02302325641312983
# Iteration number  8 , min , max temp  100.9161864800955 1293.3818127264797 , flux balance  -0.022248801510161658
# Iteration number  9 , min , max temp  101.9428127753275 1293.620426061003 , flux balance  -0.02143967307594483
# Iterations exceeded it_max ! sorry
# I am updating kzz
# Overwriting some Kz values to minimum value set by kz_min
#                      You can always turn off these warnings by setting verbose=False
# Doing clouds: Max TAUCLD diff is 1.260507791835923  Tau tolerance is  9.04649064320407
# in calc_atm turning on patchy clouds
# I am thinning the cloud with a fractional component: 0
# Profile converged before itmx
# YAY ! ENDING WITH CONVERGENCE
# TODO flag in climate.py 2794 chem bundle might be out of date but currently things look good
# in justdoit picaso turning on patchy clouds
# I am thinning the cloud with a fractional component: 0

# %%
# now let's plot the results! 
pressure_bobcat,temp_bobcat = np.loadtxt(jdi.os.path.join(
                            sonora_profile_db,f"t{teff}g{grav}nc_m0.0.dat"),
                            usecols=[1,2],unpack=True, skiprows = 1)
plt.figure(figsize=(8,6))
plt.ylabel("Pressure [Bars]")
plt.xlabel('Temperature [K]')
#plt.xlim(0,max(out['temperature'])+50)
plt.ylim(3e3,1e-3)

plt.plot(h2o_cond_t,h2o_cond_p, 'b')#, label = 'H2O Condensation Curve')
plt.semilogy(temp_bobcat,pressure_bobcat,color="k",linestyle="--",linewidth=3,label="Sonora Bobcat")

plt.semilogy(out['temperature'],out['pressure'],label="Our Fully Cloudy Run")
plt.semilogy(out_patchy['temperature'],out_patchy['pressure'],label="Our Patchy Cloud Run")

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# What you should notice here, because the patchy clouds reduces the amount of cloud opacity in the atmosphere, the PT profile is not shifted to be warmer but is closer to the cloud-free Sonora Bobcat profile

# %%
opa_mon = jdi.opannection(wave_range=[0.3,15])

hi_res = jdi.inputs(calculation="browndwarf") # start a calculation
teff= 200 # Effective Temperature of your Brown Dwarf in K
grav = 1000 # Gravity of your brown dwarf in m/s/s
hi_res.gravity(gravity=grav, gravity_unit=u.Unit('m/(s**2)')) # input gravity

hi_res.atmosphere(df=out_patchy['ptchem_df'])

# now let's add the cloud optical properties, this time with arguments to make sure we take into consideration the patchy cloud parameters
hi_res.clouds(df=out_patchy['cld_df'], do_holes=True, fhole = 0.3, fthin_cld=0)

df_spec = hi_res.spectrum(opa_mon, calculation='thermal',full_output=True)
#converts from picaso default units (can also specify original unit if different from picaso via kwarg f_unit and xgrid_unit)
fluxnu= jdi.convert_flux_units(df_spec['wavenumber'], df_spec['thermal'], to_f_unit = 'erg*cm^(-2)*s^(-1)*Hz^(-1)')

df_spec['fluxnu'] = fluxnu
wno_patchy,fp_patchy= jdi.mean_regrid(df_spec['wavenumber'], fluxnu, R=200) #wavenumber, erg/cm2/s/Hz
# Out:
# in justdoit picaso turning on patchy clouds
# I am thinning the cloud with a fractional component: 0

# %%
fig = plt.figure(figsize=(12,6))
plt.loglog(1e4/wno_bobcat,fp_bobcat, 'k', label = 'Sonora Bobcat')
plt.loglog(1e4/wno,fp, label = 'Our Fully Cloudy Run')
plt.loglog(1e4/wno_patchy,fp_patchy, label = 'Our Patchy Cloud Run')
plt.xlabel('Wavelength [micron]')
plt.ylabel('F$_\\nu$ [erg/cm$^2$/s/Hz]')
plt.xlim(0.4,12)
plt.legend()
plt.show()

# %% [markdown]
# In comparison to the fully cloudy model, you can see that even at 70% cloudy that the water cloud feature at 4-5 micron isn't as distinct as the 100% cloudy model. You can, however, see in the other H2O band windows that the 70% cloudy model finds itself, as we expect, between a fully clear model, and a fully cloudy model.
